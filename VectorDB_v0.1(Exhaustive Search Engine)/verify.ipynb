# %%
import numpy as np
a = [1, 2, 3]
b = [4, 5, 6]

# %%
l2 = np.linalg.norm(np.array(a) - np.array(b))
l2
# Out:
# np.float64(5.196152422706632)

# %%
cosine = np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))
cosine
# Out:
# np.float64(0.9746318461970762)

# %%
dot = np.dot(a, b)
dot
# Out:
# np.int64(32)
